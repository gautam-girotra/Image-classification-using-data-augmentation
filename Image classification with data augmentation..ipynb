# %% [markdown]
# # Image classification with data augmentation.

# %% [markdown]
# ### Importing the required libraries.

# %%
import numpy as np
import os 
import tensorflow as tf 
import tensorflow_hub as hub
import keras
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.losses import CategoricalCrossentropy
from keras.optimizers import Adam
import matplotlib.pyplot as plt

# %% [markdown]
# ### Using the intel image classification dataset from kaggle.  Link-https://www.kaggle.com/puneet6060/intel-image-classification

# %%
train_path='./dataset/intel image/seg_train/seg_train'
valid_path='./dataset/intel image/seg_test/seg_test'

# %% [markdown]
# ### Defining base generator without data augmentation.

# %%
train_generator_base=ImageDataGenerator(rescale=1./255) # Normalizing images by rescaling them. 
valid_generator_base=ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ### Loading data directly from directory.

# %%
train_data=train_generator_base.flow_from_directory(train_path,target_size=(224,224),batch_size=16)
valid_data=valid_generator_base.flow_from_directory(valid_path,target_size=(224,224),batch_size=16)
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %% [markdown]
# ### Exploring the data.

# %%
for image_batch,label_batch in train_data:
    print('Shape of image batch is:',image_batch.shape)
    print('Shape of label batch is:',label_batch.shape)
    break
# Out:
# Shape of image batch is: (16, 224, 224, 3)
# Shape of label batch is: (16, 6)

# %%
class_names=os.listdir(train_path)
print(class_names)
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %% [markdown]
# ### Plotting sample images.

# %%
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(image_batch[i])
    plt.axis('off')

# %% [markdown]
# ### Early stopping callback to avoid overfitting.

# %%
callbacks=keras.callbacks.EarlyStopping(monitor='val_loss',verbose=2,patience=4,restore_best_weights=True)

# %% [markdown]
# ### Using tensorflow hub to download Feature vector layer which is basically a classifier without the top.

# %%
mobile_net_url='https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4'
feature_extractor_layer=hub.KerasLayer(mobile_net_url,input_shape=(224,224,3)) # Converts feature vector layer to keras layer.

# %%
feature_extractor_layer.trainable=False # Making the layer non-trainable to use the pre-loaded weights.

# %% [markdown]
# ### Adding the Dense layer with 6 units because of 6 classes in our dataset.

# %%
base_model=Sequential([feature_extractor_layer,
                       layers.Dense(6)])
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x0000019C2D6F6908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x0000019C2D6F6908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method KerasLayer.call of <tensorflow_hub.keras_layer.KerasLayer object at 0x0000019C2D6F6908>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Constant'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %% [markdown]
# ### Compiling the model.

# %%
base_model.compile(optimizer=Adam(learning_rate=0.001), 
                       loss=CategoricalCrossentropy(from_logits=True),  
                       metrics=['accuracy'])

# %% [markdown]
# ### Summary of base model.

# %%
base_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 6)                 7686
# =================================================================
# Total params: 2,265,670
# Trainable params: 7,686
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ### Training base model.

# %%
base_history=base_model.fit(train_data,epochs=20,callbacks=[callbacks],validation_data=valid_data)
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000019C2D7BC048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000019C2D7BC048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000019C2D7BC048> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 878/878 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8896WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000019D1CB341F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000019D1CB341F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000019D1CB341F8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 878/878 [==============================] - 50s 57ms/step - loss: 0.3060 - accuracy: 0.8896 - val_loss: 0.2642 - val_accuracy: 0.9060
# Epoch 2/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.2181 - accuracy: 0.9191 - val_loss: 0.2391 - val_accuracy: 0.9080
# Epoch 3/20
# 878/878 [==============================] - 50s 57ms/step - loss: 0.1914 - accuracy: 0.9293 - val_loss: 0.2306 - val_accuracy: 0.9183
# Epoch 4/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1768 - accuracy: 0.9356 - val_loss: 0.2306 - val_accuracy: 0.9110
# Epoch 5/20
# 878/878 [==============================] - 50s 57ms/step - loss: 0.1611 - accuracy: 0.9396 - val_loss: 0.2412 - val_accuracy: 0.9117
# Epoch 6/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1512 - accuracy: 0.9436 - val_loss: 0.2576 - val_accuracy: 0.9080
# Epoch 7/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1443 - accuracy: 0.9442 - val_loss: 0.2422 - val_accuracy: 0.9173
# Epoch 8/20
# 878/878 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9490Restoring model weights from the end of the best epoch.
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1358 - accuracy: 0.9490 - val_loss: 0.2585 - val_accuracy: 0.9077
# Epoch 00008: early stopping

# %%
print('Maximum validation accuracy of base data is:',max(base_history.history['val_accuracy']))
# Out:
# Maximum validation accuracy of base data is: 0.9183333516120911

# %% [markdown]
# ### Defining image data generator with augmentation.

# %%
augmented_generator=ImageDataGenerator(rescale=1./255,
                                       horizontal_flip=True,
                                       zoom_range=0.2,
                                       brightness_range=[0.5,1.0],
                                       shear_range=15,
                                       width_shift_range=[-150,150],
                                       height_shift_range=0.5)

# %% [markdown]
# ### Loading augmented data from directory.

# %%
aug_train_data=augmented_generator.flow_from_directory(train_path,target_size=(224,224),batch_size=16)
aug_valid_data=augmented_generator.flow_from_directory(valid_path,target_size=(224,224),batch_size=16)
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %% [markdown]
# ### Defining model which will use augmentation.

# %%
aug_model=Sequential([feature_extractor_layer,
                       layers.Dense(6)])

# %% [markdown]
# ### Compiling the model.

# %%
aug_model.compile(optimizer=Adam(learning_rate=0.001),
                       loss=CategoricalCrossentropy(from_logits=True),
                       metrics=['accuracy'])

# %% [markdown]
# ### Summary of model.

# %%
aug_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 7686
# =================================================================
# Total params: 2,265,670
# Trainable params: 7,686
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# ### Training the model.

# %%
aug_history=aug_model.fit(train_data,epochs=20,callbacks=[callbacks],validation_data=valid_data)
# Out:
# Epoch 1/20
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000019D24865558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000019D24865558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x0000019D24865558> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 878/878 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8888WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000019D24A8D438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000019D24A8D438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x0000019D24A8D438> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 878/878 [==============================] - 50s 57ms/step - loss: 0.3121 - accuracy: 0.8888 - val_loss: 0.2527 - val_accuracy: 0.9083
# Epoch 2/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.2180 - accuracy: 0.9203 - val_loss: 0.2482 - val_accuracy: 0.9047
# Epoch 3/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1974 - accuracy: 0.9245 - val_loss: 0.2268 - val_accuracy: 0.9203
# Epoch 4/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1760 - accuracy: 0.9345 - val_loss: 0.2610 - val_accuracy: 0.9043
# Epoch 5/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1650 - accuracy: 0.9386 - val_loss: 0.2394 - val_accuracy: 0.9183
# Epoch 6/20
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1495 - accuracy: 0.9446 - val_loss: 0.2484 - val_accuracy: 0.9110
# Epoch 7/20
# 877/878 [============================>.] - ETA: 0s - loss: 0.1417 - accuracy: 0.9469Restoring model weights from the end of the best epoch.
# 878/878 [==============================] - 49s 56ms/step - loss: 0.1420 - accuracy: 0.9468 - val_loss: 0.2510 - val_accuracy: 0.9073
# Epoch 00007: early stopping

# %%
print('Maximum validation accuracy of augmented data is:',max(aug_history.history['val_accuracy']))
# Out:
# Maximum validation accuracy of augmented data is: 0.9203333258628845

# %% [markdown]
# ### Best validation accuracy of augmented data is slightly better than that of non augmented data.
